# %% [markdown]
# <a href="https://colab.research.google.com/github/shiri9/Federated-Machine-Learning/blob/main/figures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Data
epochs = [5, 10, 15, 20, 25, 30]
cl_loss = [1.05, 1.37, 2.29, 4.9, 3.77, 5.5]
fl_loss = [0.03, 0.02, 0.02, 0.01, 0.01, 0.01]

# Create the graph with a logarithmic y-axis
plt.figure(figsize=(8, 6))
plt.semilogy(epochs, cl_loss, marker='o', label='CL', color='red', linestyle='-', linewidth=2, markersize=8)
plt.semilogy(epochs, fl_loss, marker='s', label='FL', color='blue', linestyle='-', linewidth=2, markersize=8)

# Set labels and title
plt.xlabel('Epochs')
plt.ylabel('Loss (log scale)')
plt.legend()

# Show the graph
plt.grid(True)

# Save the plot as a PNG image
plt.savefig('loss.png')

plt.show()

# %%
import matplotlib.pyplot as plt

# Simulation times for LSTM and CNN (in seconds)
lstm_simulation_time = 444.71
cnn_simulation_time = 743.32

# Accuracy for LSTM and CNN (converted to percentage)
lstm_accuracy = 93.12
cnn_accuracy = 92.38

# Precision for LSTM and CNN (converted to percentage)
lstm_precision = 95.36
cnn_precision = 95.36

# Recall for LSTM and CNN (converted to percentage)
lstm_recall = 66.18
cnn_recall = 64.48

# F1 Score for LSTM and CNN (converted to percentage)
lstm_f1 = 70.83
cnn_f1 = 70.10

# Metrics names (excluding test loss)
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']

# Values for LSTM and CNN (excluding test loss)
lstm_values = [lstm_accuracy, lstm_precision, lstm_recall, lstm_f1]
cnn_values = [cnn_accuracy, cnn_precision, cnn_recall, cnn_f1]

# Number of metrics
num_metrics = len(metrics)

# Create subplots
fig, ax = plt.subplots(figsize=(8, 6))
index = range(num_metrics)

# Bar width
bar_width = 0.35

# Define custom colors using hexadecimal values (darker shades)
lstm_color = 'royalblue'  # Darker salmon
cnn_color = 'lightblue'   # Darker royal blue

# Plot bars for LSTM and CNN with custom colors
plt.bar(index, lstm_values, bar_width, label='LSTM', color=lstm_color, alpha=0.7, hatch="//")
plt.bar([i + bar_width for i in index], cnn_values, bar_width, label='CNN', color=cnn_color, alpha=0.7, hatch="\\")

# Set labels, title, and legend
plt.xlabel('Metrics')
plt.ylabel('Values (%)')
plt.title('CL')
plt.xticks([i + bar_width/2 for i in index], metrics)
plt.legend()

# Show the plot
plt.tight_layout()

# Save the plot as a PNG image
plt.savefig('CL-comparisonOfMetricsBetweenLSTMandCNN.png')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the metrics
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score']

# Define the FL and CL values as percentages (multiply by 100)
fl_values = [0.9931732763280751, 0.955695046171791, 0.6300334838223873, 0.6775570205457274]
cl_values = [0.9290720369056068, 0.9528672538631785, 0.6372885898925746, 0.6815106316114095]

fl_values_percentage = [value * 100 for value in fl_values]
cl_values_percentage = [value * 100 for value in cl_values]

# Create a bar graph with gradient bars
x = np.arange(len(metrics))
width = 0.35

fig, ax = plt.subplots(figsize=(8, 6))
bar1 = ax.bar(x - width/2, cl_values_percentage, width, label='CL', color='royalblue', hatch='//')
bar2 = ax.bar(x + width/2, fl_values_percentage, width, label='FL', color='lightblue', hatch='\\')

ax.set_xlabel('Metrics')
ax.set_ylabel('Values (%)')  # Set the y-axis label to indicate percentages

ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

plt.ylim(0, 100)  # Set the y-axis limit to the range [0, 100] for percentages
plt.tight_layout()

plt.grid()

# Save the plot as a PNG image
plt.savefig('model_comp.png')

# Show the graph
plt.show()

# %%
import matplotlib.pyplot as plt

# Training history for CNN and LSTM
cnn_training_loss = [0.0963, 0.0344, 0.0273, 0.0234, 0.0208, 0.0186, 0.0169, 0.0155, 0.0148, 0.0135, 0.0131, 0.0126, 0.0122, 0.0113, 0.0111, 0.0108, 0.0106, 0.0098, 0.0099, 0.0097]
lstm_training_loss = [0.0582, 0.0286, 0.0236, 0.0199, 0.0179, 0.0162, 0.0146, 0.0142, 0.0131, 0.0124, 0.0127, 0.0119, 0.0119, 0.0111, 0.0107, 0.0102, 0.0099, 0.0103, 0.0098, 0.0098]

# Number of epochs
epochs = range(1, len(cnn_training_loss) + 1)

# Plot training loss for CNN and LSTM
plt.figure(figsize=(8, 6))
plt.plot(epochs, cnn_training_loss, marker='s', linestyle='-', color='b', label='CNN')
plt.plot(epochs, lstm_training_loss, marker='o', linestyle='-', color='r', label='LSTM')
plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.grid(True)
plt.title('CL')
plt.legend()

# Save the plot as a PNG image
plt.savefig('CL-convergence-training-loss-over-epochs.png')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Data
selected_learning_rates = [0, 0.001, 0.003, 0.01]
batch_sizes = [32, 64, 128]

fl_accuracy = {
    32: [0.99, 0.99, 0.99, 0.99],
    64: [0.99, 0.99, 0.99, 0.99],
    128: [0.99, 0.99, 0.99, 0.99]
}

# Create a figure and axis
fig, ax = plt.subplots(figsize=(8, 6))

# Set the line styles and markers for each batch size
line_styles = ['-', '--', ':']
markers = ['o', 'x', '^']

# Define custom dark colors
colors = ['blue', 'red', 'black']

# Plot FL accuracy for each batch size
for i, batch_size in enumerate(batch_sizes):
    fl_accuracies = [fl_accuracy[batch_size][selected_learning_rates.index(lr)] * 100 for lr in selected_learning_rates]  # Convert to percentage
    ax.plot(selected_learning_rates, fl_accuracies, linestyle=line_styles[i], marker=markers[i], label=f'batch size = {batch_size}', color=colors[i])

# Set labels and title
ax.set_xlabel('Learning Rate')
ax.set_ylabel('Testing Accuracy (%)')
ax.set_title('FL')

# Add a grid for better visibility
ax.grid(True, linestyle='--', alpha=0.7)

# Customize legend
ax.legend(loc='lower right')

# Set y-axis limits between 90% and 100%
ax.set_ylim(80, 100)

# Format y-axis tick labels as percentages
def percentage_formatter(x, pos):
    return f'{x:.0f}%'

ax.yaxis.set_major_formatter(FuncFormatter(percentage_formatter))

# Save the plot as a PNG image
plt.savefig('FL-batch_learn.png')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Data
selected_learning_rates = [0, 0.001, 0.003, 0.01]
batch_sizes = [32, 64, 128]

cl_accuracy = {
    32: [0.91, 0.93, 0.92, 0.91],
    64: [0.91, 0.92, 0.92, 0.91],
    128: [0.91, 0.91, 0.92, 0.92]
}

# Create a figure and axis with 8x6 inches size
fig, ax = plt.subplots(figsize=(8, 6))

# Set custom dark colors for lines and markers
colors = ['red', 'blue', 'black']

# Set the line styles and markers for each batch size
line_styles = ['-', '--', ':']
markers = ['o', 'x', '^']

# Plot CL accuracy for each batch size
for i, batch_size in enumerate(batch_sizes):
    cl_accuracies = [cl_accuracy[batch_size][selected_learning_rates.index(lr)] * 100 for lr in selected_learning_rates]  # Convert to percentage
    ax.plot(selected_learning_rates, cl_accuracies, linestyle=line_styles[i], marker=markers[i], label=f'batch size = {batch_size}', color=colors[i])

# Set labels and title
ax.set_xlabel('Learning Rate')
ax.set_ylabel('Testing Accuracy (%)')
ax.set_title('CL')
ax.legend()

# Set y-axis limits between 90% and 100%
ax.set_ylim(80, 100)

# Format y-axis tick labels as percentages
def percentage_formatter(x, pos):
    return f'{x:.0f}%'

ax.yaxis.set_major_formatter(FuncFormatter(percentage_formatter))

# Save the plot as a PNG image
plt.savefig('CL-batch_learn.png')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
epochs = [5, 10, 15, 20, 25, 30]
cl_accuracy = [92, 93, 92, 91, 92, 91]
fl_accuracy = [99, 99, 99, 99, 99, 99]

# Create a figure and axis with a specific figure size (8x6 inches)
fig, ax = plt.subplots(figsize=(8, 6))

# Plot CL accuracy with lines and markers at epoch points (using red color)
ax.plot(epochs, cl_accuracy, marker='o', linestyle='-', label='CL', color='red')

# Plot FL accuracy with lines and markers at epoch points (using blue color)
ax.plot(epochs, fl_accuracy, marker='s', linestyle='-', label='FL', color='blue')

# Set labels and title
ax.set_xlabel('Epochs')
ax.set_ylabel('Testing Accuracy (%)')
ax.grid(True)

# Add a legend
ax.legend()

# Set y-axis limits between 50 and 100
ax.set_ylim(50, 100)

# Set x-axis ticks to only display specified epoch values
ax.set_xticks(epochs)

# Save the plot as a PNG image
plt.savefig('acc_vs_epochs.png')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Data for FL Batch Size Tuning
selected_learning_rates_fl = [0, 0.001, 0.003, 0.01]
batch_sizes_fl = [32, 64, 128]
fl_accuracy = {
    32: [0.99, 0.99, 0.99, 0.99],
    64: [0.99, 0.99, 0.99, 0.99],
    128: [0.99, 0.99, 0.99, 0.99]
}

# Data for CL Batch Size Tuning
selected_learning_rates_cl = [0, 0.001, 0.003, 0.01]
batch_sizes_cl = [32, 64, 128]
cl_accuracy = {
    32: [0.91, 0.93, 0.92, 0.91],
    64: [0.91, 0.92, 0.92, 0.91],
    128: [0.91, 0.91, 0.92, 0.92]
}

# Data for Epoch Tuning
epochs = [5, 10, 15, 20, 25, 30]
cl_accuracy_epochs = [92, 93, 92, 91, 92, 91]
fl_accuracy_epochs = [99, 99, 99, 99, 99, 99]

# Create a figure with three subplots arranged horizontally
fig, axes = plt.subplots(1, 3, figsize=(15, 5))  # Compact size

# Plot "a) FL Batch Size Tuning"
for i, batch_size in enumerate(batch_sizes_fl):
    fl_accuracies = [fl_accuracy[batch_size][selected_learning_rates_fl.index(lr)] * 100 for lr in selected_learning_rates_fl]  # Convert to percentage
    axes[0].plot(selected_learning_rates_fl, fl_accuracies, linestyle=line_styles[i], marker=markers[i], label=f'batch size = {batch_size}', color=colors[i])
axes[0].set_xlabel('Learning Rate')
axes[0].set_ylabel('Testing Accuracy (%)')
axes[0].legend(loc='lower right')
axes[0].set_ylim(80, 100)
axes[0].grid(True, linestyle='--', alpha=0.7)
# Add label "a)"
axes[0].text(0.5, -0.2, "a) Batch size and Learning rate tuning (FL)", transform=axes[0].transAxes, ha='center')

# Plot "b) CL Batch Size Tuning"
for i, batch_size in enumerate(batch_sizes_cl):
    cl_accuracies = [cl_accuracy[batch_size][selected_learning_rates_cl.index(lr)] * 100 for lr in selected_learning_rates_cl]  # Convert to percentage
    axes[1].plot(selected_learning_rates_cl, cl_accuracies, linestyle=line_styles[i], marker=markers[i], label=f'batch size = {batch_size}', color=colors[i])
axes[1].set_xlabel('Learning Rate')
axes[1].set_ylabel('Testing Accuracy (%)')
axes[1].legend(loc='lower right')
axes[1].set_ylim(80, 100)
axes[1].grid(True, linestyle='--', alpha=0.7)
# Add label "b)"
axes[1].text(0.5, -0.2, "b) Batch size and Learning rate tuning (CL)", transform=axes[1].transAxes, ha='center')

# Plot "c) Epoch Tuning"
axes[2].plot(epochs, cl_accuracy_epochs, marker='o', linestyle='-', label='CL', color='red')
axes[2].plot(epochs, fl_accuracy_epochs, marker='s', linestyle='-', label='FL', color='blue')
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Testing Accuracy (%)')
axes[2].legend()
axes[2].set_ylim(50, 100)
axes[2].set_xticks(epochs)
axes[2].grid(True)
# Add label "c)"
axes[2].text(0.5, -0.2, "c) Epoch tuning for CL and FL", transform=axes[2].transAxes, ha='center')

# Adjust the layout to prevent overlapping
plt.tight_layout()

# Save the combined plot as a PNG image
plt.savefig('hyperparameter_tuning_combined.png')

# Show the combined plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for FL and CL training loss
rounds = list(range(1, 21))

fl_loss = [
    0.09649372818137561, 0.05300187722260964, 0.04285150852873106, 0.035803473881312275,
    0.033079274156921086, 0.031474802849232514, 0.029568596492233527, 0.0286105772598289,
    0.02607978816505021, 0.024749611879632524, 0.025053109273088514, 0.024426539847021568,
    0.021928583124816048, 0.023194190911091966, 0.021561155202493635, 0.02057572119139443,
    0.019819465022830655, 0.019688160961200636, 0.018731341252651378, 0.01907506213757894
]

cl_loss = [
    0.0963, 0.0344, 0.0273, 0.0234, 0.0208, 0.0186, 0.0169, 0.0155, 0.0148, 0.0135,
    0.0131, 0.0126, 0.0122, 0.0113, 0.0111, 0.0108, 0.0106, 0.0098, 0.0099, 0.0097
]

# Calculate RMSE between FL and CL training loss
rmse = np.sqrt(np.mean((np.array(fl_loss) - np.array(cl_loss))**2))

# Create a figure and axis
fig, ax = plt.subplots(figsize=(8, 6))

# Plot FL training loss
ax.plot(rounds, fl_loss, marker='o', linestyle='-', label='FL', color='blue')

# Plot CL training loss
ax.plot(rounds, cl_loss, marker='s', linestyle='-', label='CL', color='red')

# Set labels and title
ax.set_xlabel('Epochs')
ax.set_ylabel('Training Loss')

# Add RMSE value to the plot
ax.annotate(f'RMSE: {rmse:.4f}', xy=(0.7, 0.1), xycoords='axes fraction', fontsize=12, color='green')

# Add a legend
ax.legend()

# Show the plot
plt.grid(True)

# Save the combined plot as a PNG image
plt.savefig('train_loss_cl_fl_cnn.png')

plt.show()

# %%
import numpy as np

# Assuming you have the FL and CL loss values in two lists
fl_loss = [0.09649372818137561, 0.05300187722260964, 0.04285150852873106, 0.035803473881312275, 0.033079274156921086, 0.031474802849232514, 0.029568596492233527, 0.0286105772598289, 0.02607978816505021, 0.024749611879632524, 0.025053109273088514, 0.024426539847021568, 0.021928583124816048, 0.023194190911091966, 0.021561155202493635, 0.02057572119139443, 0.019819465022830655, 0.019688160961200636, 0.018731341252651378, 0.01907506213757894]
cl_loss = [0.0963, 0.0344, 0.0273, 0.0234, 0.0208, 0.0186, 0.0169, 0.0155, 0.0148, 0.0135, 0.0131, 0.0126, 0.0122, 0.0113, 0.0111, 0.0108, 0.0106, 0.0098, 0.0099, 0.0097]

# Convert the lists to numpy arrays
fl_loss = np.array(fl_loss)
cl_loss = np.array(cl_loss)

# Calculate the mean squared error (MSE)
mse = np.mean((fl_loss - cl_loss)**2)

# Calculate the mean absolute error (MAE)
mae = np.mean(np.abs(fl_loss - cl_loss))

# Calculate the root mean squared error (RMSE)
rmse = np.sqrt(mse)

# Calculate the relative error as a percentage
relative_error = np.mean(np.abs(fl_loss - cl_loss) / cl_loss) * 100

print(f"MSE: {mse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"Relative Error (%): {relative_error:.2f}%")
# Out:
# MSE: 0.0001
# MAE: 0.0112
# RMSE: 0.0117
# Relative Error (%): 77.01%

# %%
import matplotlib.pyplot as plt
import numpy as np

# FL and CL training loss values
fl_loss = np.array([0.1617, 0.1037, 0.0773, 0.0610, 0.0530, 0.0484, 0.0444, 0.0415, 0.0393, 0.0368, 0.0364, 0.0348, 0.0334, 0.0331, 0.0317, 0.0310, 0.0301, 0.0310, 0.0298, 0.0299])
cl_loss = np.array([0.0582, 0.0286, 0.0236, 0.0199, 0.0179, 0.0162, 0.0146, 0.0142, 0.0131, 0.0124, 0.0127, 0.0119, 0.0119, 0.0111, 0.0107, 0.0102, 0.0099, 0.0103, 0.0098, 0.0098])

# Calculate the RMSE
rmse = np.sqrt(np.mean((fl_loss - cl_loss)**2))

# Create a figure and axis
fig, ax = plt.subplots(figsize=(8, 6))

# Plot FL and CL training loss values
rounds = range(1, len(fl_loss) + 1)
ax.plot(rounds, fl_loss, label='FL', marker='o', linestyle='-', color='blue')
ax.plot(rounds, cl_loss, label='CL', marker='s', linestyle='-', color='red')

# Set labels and title
ax.set_xlabel('Epochs')
ax.set_ylabel('Training Loss')
ax.grid(True)

# Add RMSE value to the plot
ax.annotate(f'RMSE: {rmse:.4f}', xy=(0.7, 0.1), xycoords='axes fraction', fontsize=12, color='green')

# Add legend
ax.legend()

# Save the combined plot as a PNG image
plt.savefig('train_loss_cl_fl_lstm.png')

# Show the plot
plt.show()

# %%
from google.colab import files

# Download the plot
files.download('train_loss_cl_fl_lstm.png')
